# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
endpoint = 'https://fantasy.espn.com/apis/v3/games/ffl/seasons/2021/segments/0/leagues/69192084'
params = {
            'view': ['mTeam']
        }
espn_s2='AECtBC8t2p%2F1HWtD9xwcZTJbKZnmIy2jPmG6JJMKDE7WjJ0YmGBLZG7i%2FOkb5aGb%2F%2BpKL%2Bxe33dXnl%2F6MDJwDbrD2thKx0SwXDB2wRJF%2F0oompDwq04%2BoR9qoX0777%2Bksnn2Hr55WelNUxLArj4Ea2XCCDCTO4S%2BgW147eUAqFSf28q93COtLYtnFk1uxKRkm2awp2ZxVycaBI2TMGeC1UNYUoP2wJBw%2F9s%2F2BPJKUC6hz8NtlXO2lSauKcY4cGxfSHfrfnOf0kgfJIJephWMeXYox9Hb7e7MRmd1TwLuL%2FP2w%3D%3D'
swid='{832BF702-905D-40ED-ABF7-02905D90EDB1}'

r = requests.get(url=endpoint, params=params, headers=None, cookies={
                'espn_s2': espn_s2,
                'SWID': swid
            })


df = pd.json_normalize(r.json())

# %%
df.head()
# Out:
#    gameId        id                                            members  \
# 0       1  69192084  [{'displayName': 'KennyKanDo69', 'firstName': ...
#
#    scoringPeriodId  seasonId  segmentId  \
# 0               19      2021          0
#
#                                                teams  draftDetail.drafted  \
# 0  [{'abbrev': 'Spoo', 'currentProjectedRank': 4,...                 True
#
#    draftDetail.inProgress  status.activatedDate  ...  \
# 0                   False         1630196505022  ...
#
#    status.waiverProcessStatus.2021-11-03T07:34:13.767+0000  \
# 0                                                  5
#
#    status.waiverProcessStatus.2021-11-10T09:07:38.238+0000  \
# 0                                                  5
#
#    status.waiverProcessStatus.2021-11-14T09:32:23.491+0000  \
# 0                                                  1
#
#    status.waiverProcessStatus.2021-11-17T09:14:47.206+0000  \
# 0                                                  5
#
#    status.waiverProcessStatus.2021-11-24T09:01:17.945+0000  \
# 0                                                  7
#
#    status.waiverProcessStatus.2021-12-01T09:54:20.606+0000  \
# 0                                                  3
#
#    status.waiverProcessStatus.2021-12-08T08:50:08.501+0000  \
# 0                                                  2
#
#    status.waiverProcessStatus.2021-12-15T09:29:38.015+0000  \
# 0                                                  3
#
#    status.waiverProcessStatus.2021-12-23T09:11:53.139+0000  \
# 0                                                  3
#
#    status.waiverProcessStatus.2021-12-29T08:54:37.090+0000
# 0                                                  1
#
# [1 rows x 51 columns]

# %%
member_list = []
for i in df['members']:
    for j in i:
        member_list.append((j['firstName'], j['lastName'], j['displayName'], j['id']))

print(member_list)
# Out:
# [('Ken', 'Decker', 'KennyKanDo69', '{0DF78572-6CBE-4455-B785-726CBE24559C}'), ('Aaron', 'Lechner', 'lechman91', '{39205D6C-3058-46C7-A0C8-1FF6437DB860}'), ('Drew', 'Ortega', 'U of A all the Way', '{4C367868-17A3-4B68-A280-E945E18ACC5E}'), ('Joss', 'Delaune', 'Joss the boss', '{55B21CD1-73B3-48C9-9794-0EC5C79719F6}'), ('Andrew', 'Lichtsinn', 'AndyLixon', '{6BAF20AE-DB4E-46D0-9B39-D9630AFD3407}'), ('Justin', 'Hsieh', 'Ju$ty', '{832BF702-905D-40ED-ABF7-02905D90EDB1}'), ('Logan', 'Mathesen', 'espn00804850', '{B3C40C73-BA93-4541-B8C9-14E44AAC9331}'), ('Tim', 'Cable', 'timc12', '{DA39D8FC-2597-4AB6-BB7E-B8E6E784E7A9}'), ('Ed', 'A', 'Goldmine_49', '{DA78EFA0-DCDA-4F8B-A0A7-0D20896754DE}'), ('Carl', 'Harper', 'espn65894228', '{FD9BFC91-CB83-4F18-AA2C-2E01D84A51A5}')]

# %%
df1 = pd.DataFrame(member_list)
df1
# Out:
#         0          1                   2  \
# 0     Ken     Decker        KennyKanDo69
# 1   Aaron    Lechner           lechman91
# 2    Drew     Ortega  U of A all the Way
# 3    Joss    Delaune       Joss the boss
# 4  Andrew  Lichtsinn           AndyLixon
# 5  Justin      Hsieh               Ju$ty
# 6   Logan   Mathesen        espn00804850
# 7     Tim      Cable              timc12
# 8      Ed          A         Goldmine_49
# 9    Carl     Harper        espn65894228
#
#                                         3
# 0  {0DF78572-6CBE-4455-B785-726CBE24559C}
# 1  {39205D6C-3058-46C7-A0C8-1FF6437DB860}
# 2  {4C367868-17A3-4B68-A280-E945E18ACC5E}
# 3  {55B21CD1-73B3-48C9-9794-0EC5C79719F6}
# 4  {6BAF20AE-DB4E-46D0-9B39-D9630AFD3407}
# 5  {832BF702-905D-40ED-ABF7-02905D90EDB1}
# 6  {B3C40C73-BA93-4541-B8C9-14E44AAC9331}
# 7  {DA39D8FC-2597-4AB6-BB7E-B8E6E784E7A9}
# 8  {DA78EFA0-DCDA-4F8B-A0A7-0D20896754DE}
# 9  {FD9BFC91-CB83-4F18-AA2C-2E01D84A51A5}

# %%
team_list = []
for i in df['teams']:
    for j in i:
        team_list.append((j['abbrev'], j['location'] + ' ' + j['nickname'], j['id'], j['primaryOwner']))

print(team_list)
# Out:
# [('Spoo', 'Richard Ed Down', 1, '{832BF702-905D-40ED-ABF7-02905D90EDB1}'), ('HARP', 'Tequila Cowboy', 2, '{FD9BFC91-CB83-4F18-AA2C-2E01D84A51A5}'), ('AJL', 'You Hate to See That', 3, '{6BAF20AE-DB4E-46D0-9B39-D9630AFD3407}'), ('DECK', 'Punter? I Hardly Know Her', 4, '{0DF78572-6CBE-4455-B785-726CBE24559C}'), ('LECH', 'Ma heart Mahomes', 5, '{39205D6C-3058-46C7-A0C8-1FF6437DB860}'), ('CABL', 'I h8 justin', 6, '{DA39D8FC-2597-4AB6-BB7E-B8E6E784E7A9}'), ('LGW!', 'Lets Get  Weird 🐸', 7, '{B3C40C73-BA93-4541-B8C9-14E44AAC9331}'), ('PP ', 'Justin likes to Tuck-er', 10, '{55B21CD1-73B3-48C9-9794-0EC5C79719F6}'), ('Kp', 'Kareem Punt', 11, '{DA78EFA0-DCDA-4F8B-A0A7-0D20896754DE}'), ('RI', 'Geaux  Small Hands', 12, '{4C367868-17A3-4B68-A280-E945E18ACC5E}')]

# %%
df2 = pd.DataFrame(team_list)
df2
# Out:
#       0                          1   2                                       3
# 0  Spoo            Richard Ed Down   1  {832BF702-905D-40ED-ABF7-02905D90EDB1}
# 1  HARP             Tequila Cowboy   2  {FD9BFC91-CB83-4F18-AA2C-2E01D84A51A5}
# 2   AJL       You Hate to See That   3  {6BAF20AE-DB4E-46D0-9B39-D9630AFD3407}
# 3  DECK  Punter? I Hardly Know Her   4  {0DF78572-6CBE-4455-B785-726CBE24559C}
# 4  LECH           Ma heart Mahomes   5  {39205D6C-3058-46C7-A0C8-1FF6437DB860}
# 5  CABL                I h8 justin   6  {DA39D8FC-2597-4AB6-BB7E-B8E6E784E7A9}
# 6  LGW!          Lets Get  Weird 🐸   7  {B3C40C73-BA93-4541-B8C9-14E44AAC9331}
# 7   PP     Justin likes to Tuck-er  10  {55B21CD1-73B3-48C9-9794-0EC5C79719F6}
# 8    Kp                Kareem Punt  11  {DA78EFA0-DCDA-4F8B-A0A7-0D20896754DE}
# 9    RI         Geaux  Small Hands  12  {4C367868-17A3-4B68-A280-E945E18ACC5E}

# %%
df.columns
# Out:
# Index(['gameId', 'id', 'members', 'scoringPeriodId', 'seasonId', 'segmentId',
#        'teams', 'draftDetail.drafted', 'draftDetail.inProgress',
#        'status.activatedDate', 'status.createdAsLeagueType',
#        'status.currentLeagueType', 'status.currentMatchupPeriod',
#        'status.finalScoringPeriod', 'status.firstScoringPeriod',
#        'status.isActive', 'status.isExpired', 'status.isFull',
#        'status.isPlayoffMatchupEdited', 'status.isToBeDeleted',
#        'status.isViewable', 'status.isWaiverOrderEdited',
#        'status.latestScoringPeriod', 'status.previousSeasons',
#        'status.standingsUpdateDate', 'status.teamsJoined',
#        'status.transactionScoringPeriod', 'status.waiverLastExecutionDate',
#        'status.waiverProcessStatus.2021-09-06T07:15:49.037+0000',
#        'status.waiverProcessStatus.2021-09-15T07:42:36.271+0000',
#        'status.waiverProcessStatus.2021-09-16T07:22:52.974+0000',
#        'status.waiverProcessStatus.2021-09-22T07:54:30.262+0000',
#        'status.waiverProcessStatus.2021-09-29T07:30:39.325+0000',
#        'status.waiverProcessStatus.2021-10-06T08:20:01.526+0000',
#        'status.waiverProcessStatus.2021-10-13T07:58:49.435+0000',
#        'status.waiverProcessStatus.2021-10-14T07:46:29.542+0000',
#        'status.waiverProcessStatus.2021-10-15T07:16:20.952+0000',
#        'status.waiverProcessStatus.2021-10-20T07:47:25.167+0000',
#        'status.waiverProcessStatus.2021-10-21T08:30:54.164+0000',
#        'status.waiverProcessStatus.2021-10-22T11:04:51.625+0000',
#        'status.waiverProcessStatus.2021-10-27T07:10:29.416+0000',
#        'status.waiverProcessStatus.2021-11-03T07:34:13.767+0000',
#        'status.waiverProcessStatus.2021-11-10T09:07:38.238+0000',
#        'status.waiverProcessStatus.2021-11-14T09:32:23.491+0000',
#        'status.waiverProcessStatus.2021-11-17T09:14:47.206+0000',
#        'status.waiverProcessStatus.2021-11-24T09:01:17.945+0000',
#        'status.waiverProcessStatus.2021-12-01T09:54:20.606+0000',
#        'status.waiverProcessStatus.2021-12-08T08:50:08.501+0000',
#        'status.waiverProcessStatus.2021-12-15T09:29:38.015+0000',
#        'status.waiverProcessStatus.2021-12-23T09:11:53.139+0000',
#        'status.waiverProcessStatus.2021-12-29T08:54:37.090+0000'],
#       dtype='object')

# %%
print(rr['scoringPeriodId'])
# Out:
# 19

# %%
endpoint = 'https://fantasy.espn.com/apis/v3/games/ffl/seasons/2022/segments/0/leagues/69192084'
params = {
            'view': ['mTeam']
        }
espn_s2='AECtBC8t2p%2F1HWtD9xwcZTJbKZnmIy2jPmG6JJMKDE7WjJ0YmGBLZG7i%2FOkb5aGb%2F%2BpKL%2Bxe33dXnl%2F6MDJwDbrD2thKx0SwXDB2wRJF%2F0oompDwq04%2BoR9qoX0777%2Bksnn2Hr55WelNUxLArj4Ea2XCCDCTO4S%2BgW147eUAqFSf28q93COtLYtnFk1uxKRkm2awp2ZxVycaBI2TMGeC1UNYUoP2wJBw%2F9s%2F2BPJKUC6hz8NtlXO2lSauKcY4cGxfSHfrfnOf0kgfJIJephWMeXYox9Hb7e7MRmd1TwLuL%2FP2w%3D%3D'
swid='{832BF702-905D-40ED-ABF7-02905D90EDB1}'

r = requests.get(url=endpoint, params=params, headers=None, cookies={
                'espn_s2': espn_s2,
                'SWID': swid
            })


df_test = pd.json_normalize(r.json())

# %%
df_test.head()
# Out:
#    gameId        id                                            members  \
# 0       1  69192084  [{'displayName': 'KennyKanDo69', 'firstName': ...
#
#    scoringPeriodId  seasonId  segmentId  \
# 0                1      2022          0
#
#                                                teams  draftDetail.drafted  \
# 0  [{'abbrev': 'Spoo', 'currentProjectedRank': 5,...                 True
#
#    draftDetail.inProgress  status.activatedDate  ...  \
# 0                   False         1660680401164  ...
#
#    status.isPlayoffMatchupEdited  status.isToBeDeleted  status.isViewable  \
# 0                          False                 False              False
#
#    status.isWaiverOrderEdited  status.latestScoringPeriod  \
# 0                       False                           1
#
#    status.previousSeasons  status.standingsUpdateDate  status.teamsJoined  \
# 0      [2019, 2020, 2021]               1661740809630                  12
#
#    status.transactionScoringPeriod  status.waiverLastExecutionDate
# 0                                1                   1661758718674
#
# [1 rows x 28 columns]
